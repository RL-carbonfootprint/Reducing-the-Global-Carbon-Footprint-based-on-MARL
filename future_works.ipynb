# %%
#importing libs
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#loading dataFrames
LT_df = pd.read_csv('./metadata/LT_db.csv', index_col=0)
MT_df = pd.read_csv('./metadata/MT_db.csv', index_col=0)
ST_df = pd.read_csv('./metadata/ST_db.csv', index_col=0)
LT_df.head()
# Out:
#        1985      1986      1987      1988      1989      1990      1991  \
# 0  0.031377  0.030028  0.036176  0.030818  0.029076  0.028706  0.027628
# 1  0.093806  0.094065  0.085197  0.082286  0.098226  0.059224  0.046310
# 2  0.070727  0.063203  0.060189  0.057532  0.061108  0.055050  0.056957
# 3  0.042733  0.043573  0.047311  0.049234  0.046751  0.044131  0.045438
# 4  0.042411  0.042433  0.046829  0.048660  0.048474  0.047455  0.044394
#
#        1992      1993      1994  ...      2005      2006      2007      2008  \
# 0  0.027295  0.029370  0.019157  ...  0.065541  0.073472  0.079996  0.078790
# 1  0.027341  0.025544  0.021182  ...  0.049850  0.045970  0.046668  0.052384
# 2  0.054808  0.058760  0.061687  ...  0.048992  0.045232  0.042550  0.042956
# 3  0.046456  0.044559  0.045671  ...  0.053501  0.057314  0.056660  0.060562
# 4  0.043036  0.043353  0.041859  ...  0.055345  0.056380  0.058703  0.059114
#
#        2009      2010      2011      2012      2013      2014
# ...

# %%
LT_values = LT_df.values[:-1]
Population_LT = LT_df.values[-1]

# %%
plt.figure(figsize=(16, 8))
plt.plot(np.arange(0, len(LT_values.ravel())), LT_values.ravel())
plt.legend(['LT group of countries'])
plt.yticks(np.arange(0, 0.1, 0.01))
plt.ylabel('values')
plt.xlabel('CO2 Emission datapoints')
plt.show()

# %%
MT_values = MT_df.values[:-1]
Population_MT = MT_df.values[-1]

# %%
plt.figure(figsize=(16, 8))
plt.plot(np.arange(0, len(MT_values.ravel())), MT_values.ravel())
plt.legend(['MT group of countries'])
plt.yticks(np.arange(0, 0.1, 0.01))
plt.ylabel('values')
plt.xlabel('CO2 Emission datapoints')
plt.show()

# %%
ST_values = ST_df.values[:-1]
Population_ST = ST_df.values[-1]

# %%
plt.figure(figsize=(16, 8))

ST_samples= np.random.choice(ST_values.ravel(), 170, replace=True, p=None)
MT_samples= np.random.choice(MT_values.ravel(), 170, replace=True, p=None)
LT_samples= np.random.choice(LT_values.ravel(), 170, replace=True, p=None)
print(ST_samples.shape)
ST_plot=plt.plot(ST_samples, c='red', alpha=.5)
MT_plot=plt.plot(MT_samples, c='blue', alpha=.5)
LT_plot=plt.plot(LT_samples, c='green', alpha=.5)
plt.ylabel('values')
plt.title('Action space', fontsize=25)
plt.xlabel('CO2 Emission datapoints')
plt.legend((ST_plot, MT_plot, LT_plot), ("ST", "MT", "LT")) #['ST group of countries'])
#plt.yticks(np.arange(0, 0.1, 0.01))

#plt.show()
plt.savefig('/Users/thearolskovsloth//Reducing-the-Global-Carbon-Footprint-based-on-MARL/plots/action_space.png')
# Out:
# (170,)
# /var/folders/lr/m88n3jxd3ls79c_st34bhpr00000gn/T/ipykernel_3790/3242213179.py:13: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x7f8cee8d0940>] instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend((ST_plot, MT_plot, LT_plot), ("ST", "MT", "LT")) #['ST group of countries'])
# /var/folders/lr/m88n3jxd3ls79c_st34bhpr00000gn/T/ipykernel_3790/3242213179.py:13: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x7f8cee8d84f0>] instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend((ST_plot, MT_plot, LT_plot), ("ST", "MT", "LT")) #['ST group of countries'])
# ...
